# %%
# variable in python without data type
x = 10
print(x)
x = "Hello"
print(x)
# Out:
# 10
# Hello

# %%
print("Hello, World!" + " Welcome to Python programming.")
# Out:
# Hello, World! Welcome to Python programming.

# %%
name  = "Alice"
print (name + " is learning Python.")
# Out:
# Alice is learning Python.

# %%
fruits = ["apple", "banana", "cherry"]
fruits.append("orange")
print(fruits)
print(type(fruits))
# Out:
# ['apple', 'banana', 'cherry', 'orange']
# <class 'list'>

# %%
fruits = ("apple", "banana", "cherry")
print(fruits)
print(type(fruits))
# Out:
# ('apple', 'banana', 'cherry')
# <class 'tuple'>

# %%
fruits =
